# %% [markdown]
# <a href="https://colab.research.google.com/github/JingleiZhu-Jane/A14-Assignment/blob/main/Assignment1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
proj_dir = '/content/drive/MyDrive/AI4Science/TCGA_Ovarian_Cancer_(OV)'
os.chdir(proj_dir)
# !ls
# Out:
# Mounted at /content/drive
# TCGA.OV.sampleMap_HiSeqV2_PANCAN.gz  TCGA.OV.sampleMap_OV_clinicalMatrix

# %%
# !pip install precision_lasso
# Out:
# Requirement already satisfied: precision_lasso in /usr/local/lib/python3.10/dist-packages (0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from precision_lasso) (1.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from precision_lasso) (1.23.5)

# %%
import pandas as pd
import numpy as np

clinical_data = pd.read_csv('TCGA.OV.sampleMap_OV_clinicalMatrix', sep='\t', index_col=0)
gene_data = pd.read_csv('TCGA.OV.sampleMap_HiSeqV2_PANCAN.gz', sep='\t', index_col=0)

# %%
print("clinical_data")
clinical_data.head()
# Out:
# clinical_data
#                     _INTEGRATION _PANCAN_CNA_PANCAN_K8  \
# sampleID
# TCGA-01-0628-11  TCGA-01-0628-11                   NaN
# TCGA-01-0629-11  TCGA-01-0629-11                   NaN
# TCGA-01-0630-11  TCGA-01-0630-11                   NaN
# TCGA-01-0631-11  TCGA-01-0631-11                   NaN
# TCGA-01-0633-11  TCGA-01-0633-11                   NaN
#
#                 _PANCAN_Cluster_Cluster_PANCAN _PANCAN_DNAMethyl_PANCAN  \
# sampleID
# TCGA-01-0628-11                            NaN                      NaN
# TCGA-01-0629-11                            NaN                      NaN
# TCGA-01-0630-11                            NaN                      NaN
# TCGA-01-0631-11                            NaN                      NaN
# TCGA-01-0633-11                            NaN                      NaN
#
#                 _PANCAN_RPPA_PANCAN_K8 _PANCAN_UNC_RNAseq_PANCAN_K16  \
# sampleID
# TCGA-01-0628-11                    NaN                           NaN
# TCGA-01-0629-11                    NaN                           NaN
# TCGA-01-0630-11                    NaN                           NaN
# TCGA-01-0631-11                    NaN                           NaN
# TCGA-01-0633-11                    NaN                           NaN
#
#                 _PANCAN_miRNA_PANCAN _PANCAN_mirna_OV _PANCAN_mutation_PANCAN  \
# sampleID
# TCGA-01-0628-11                  NaN              NaN                     NaN
# TCGA-01-0629-11                  NaN              NaN                     NaN
# TCGA-01-0630-11                  NaN              NaN                     NaN
# TCGA-01-0631-11                  NaN              NaN                     NaN
# TCGA-01-0633-11                  NaN              NaN                     NaN
#
#                      _PATIENT  ... _GENOMIC_ID_TCGA_OV_exp_HiSeqV2_PANCAN  \
# sampleID                       ...
# TCGA-01-0628-11  TCGA-01-0628  ...                                    NaN
# TCGA-01-0629-11  TCGA-01-0629  ...                                    NaN
# TCGA-01-0630-11  TCGA-01-0630  ...                                    NaN
# TCGA-01-0631-11  TCGA-01-0631  ...                                    NaN
# TCGA-01-0633-11  TCGA-01-0633  ...                                    NaN
#
#                 _GENOMIC_ID_TCGA_OV_exp_HiSeq_exon  \
# sampleID
# TCGA-01-0628-11                                NaN
# TCGA-01-0629-11                                NaN
# TCGA-01-0630-11                                NaN
# TCGA-01-0631-11                                NaN
# TCGA-01-0633-11                                NaN
#
#                 _GENOMIC_ID_TCGA_OV_exp_HiSeqV2  \
# sampleID
# TCGA-01-0628-11                             NaN
# TCGA-01-0629-11                             NaN
# TCGA-01-0630-11                             NaN
# TCGA-01-0631-11                             NaN
# TCGA-01-0633-11                             NaN
#
#                 _GENOMIC_ID_TCGA_OV_mutation_broad_gene  \
# sampleID
# TCGA-01-0628-11                                     NaN
# TCGA-01-0629-11                                     NaN
# TCGA-01-0630-11                                     NaN
# TCGA-01-0631-11                                     NaN
# TCGA-01-0633-11                                     NaN
#
#                 _GENOMIC_ID_TCGA_OV_PDMarrayCNV  \
# sampleID
# TCGA-01-0628-11                             NaN
# TCGA-01-0629-11                             NaN
# TCGA-01-0630-11                             NaN
# TCGA-01-0631-11                             NaN
# TCGA-01-0633-11                             NaN
#
#                  _GENOMIC_ID_TCGA_OV_PDMRNAseqCNV  \
# sampleID
# TCGA-01-0628-11                               NaN
# TCGA-01-0629-11                               NaN
# TCGA-01-0630-11                               NaN
# TCGA-01-0631-11                               NaN
# TCGA-01-0633-11                               NaN
#
#                 _GENOMIC_ID_TCGA_OV_exp_HiSeqV2_exon  \
# sampleID
# TCGA-01-0628-11                                  NaN
# TCGA-01-0629-11                                  NaN
# TCGA-01-0630-11                                  NaN
# TCGA-01-0631-11                                  NaN
# TCGA-01-0633-11                                  NaN
#
#                 _GENOMIC_ID_TCGA_OV_mutation _GENOMIC_ID_TCGA_OV_G4502A_07_3  \
# sampleID
# TCGA-01-0628-11                          NaN    TCGA-01-0628-11A-01R-0363-07
# TCGA-01-0629-11                          NaN    TCGA-01-0629-11A-01R-0363-07
# TCGA-01-0630-11                          NaN                             NaN
# TCGA-01-0631-11                          NaN                             NaN
# TCGA-01-0633-11                          NaN                             NaN
#
#                 _GENOMIC_ID_TCGA_OV_G4502A_07_2
# sampleID
# TCGA-01-0628-11                             NaN
# TCGA-01-0629-11                             NaN
# TCGA-01-0630-11    TCGA-01-0630-11A-01R-0363-07
# TCGA-01-0631-11    TCGA-01-0631-11A-01R-0363-07
# TCGA-01-0633-11    TCGA-01-0633-11A-01R-0363-07
#
# [5 rows x 101 columns]

# %%
print("gene_data")
gene_data.head()
# Out:
# gene_data
#            TCGA-61-1910-01  TCGA-61-1728-01  TCGA-09-1666-01  TCGA-24-1469-01  \
# sample
# ARHGEF10L        -0.262892        -0.543692        -1.668892        -1.281392
# HIF3A            -2.276126         1.810774         0.123074         4.097674
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10             0.657528         0.071628        -0.753772        -0.333972
# RNF11            -0.865078        -0.181678         0.343322        -0.507178
#
#            TCGA-04-1348-01  TCGA-61-1917-01  TCGA-61-2009-01  TCGA-31-1950-01  \
# sample
# ARHGEF10L        -1.144492        -1.773892        -1.218792         0.021308
# HIF3A             4.363674         5.661374         4.051874         3.148974
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10             0.358628        -0.616472         0.125528         0.343428
# RNF11            -0.729078        -0.145578         0.192422        -0.333178
#
#            TCGA-31-1951-01  TCGA-61-1995-01  ...  TCGA-24-1560-01  \
# sample                                       ...
# ARHGEF10L         0.249208        -1.112592  ...        -3.735192
# HIF3A             3.307474         0.231174  ...         2.480974
# RNF17            -0.068935        -0.531035  ...        -0.531035
# RNF10             0.340628         0.379628  ...         1.114828
# RNF11            -0.202478         0.047822  ...         0.893722
#
#            TCGA-29-1783-01  TCGA-59-2348-01  TCGA-24-1424-01  TCGA-13-1507-01  \
# sample
# ARHGEF10L        -0.230492         0.059708        -0.925092        -1.171692
# HIF3A             5.403474        -2.767226         4.466974        -0.019226
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10            -0.096872         0.765328         0.483628        -1.121872
# RNF11             0.551922         0.161622        -0.313878         0.401022
#
#            TCGA-25-2404-01  TCGA-61-2095-01  TCGA-29-1702-01  TCGA-24-1417-01  \
# sample
# ARHGEF10L        -0.650692         0.385408        -1.699992        -1.256792
# HIF3A             1.622274         4.484274         5.387374         3.476574
# RNF17            -0.531035         0.290565        -0.531035        -0.531035
# RNF10             0.275528         0.115528        -0.670972         0.012128
# RNF11            -0.180578        -0.228178         0.308122         0.070622
#
#            TCGA-57-1585-01
# sample
# ARHGEF10L         0.229008
# HIF3A             3.444374
# RNF17            -0.531035
# RNF10            -0.139572
# RNF11            -0.144078
#
# [5 rows x 308 columns]

# %%
condition = 'age'
condition_col = 'days_to_birth'
col_offset = len(clinical_data.columns)
num_genes = len(gene_data)

# %%
merged_data = clinical_data.join(gene_data.T)

input_cols = [condition_col] + merged_data.columns[col_offset: col_offset + num_genes].tolist()
merged_data = merged_data[input_cols]

merged_data = merged_data.dropna(how='any')

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-04-1348-01       -16236.0  -1.144492  4.363674 -0.531035  0.358628
# TCGA-04-1357-01       -18999.0  -0.681392  2.275374 -0.531035 -0.814372
# TCGA-04-1362-01       -21745.0  -0.298792  2.225074 -0.531035  0.300928
# TCGA-04-1364-01       -22294.0  -1.884192  5.459374 -0.531035 -0.296072
# TCGA-04-1365-01       -31925.0  -0.682892  1.917674 -0.531035 -0.014072
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-04-1348-01 -0.729078  0.64369  0.042406  1.447654  1.103801  ...
# TCGA-04-1357-01 -0.131978  0.10519  0.854706  0.423254  0.299901  ...
# TCGA-04-1362-01  0.047622 -0.65201 -0.421194  2.968654  1.154701  ...
# TCGA-04-1364-01 -0.551278 -0.97961  1.181606  2.309254  1.007501  ...
# TCGA-04-1365-01 -0.229678 -0.95741  0.478706  0.611454  0.902401  ...
#
#                     TULP2     NPY5R     GNGT2    GNGT1     TULP3      PTRF  \
# sampleID
# TCGA-04-1348-01 -0.127978 -0.966217  0.660767  1.89921  0.277323 -0.963686
# TCGA-04-1357-01 -0.748878 -1.587117  1.654867  2.59361  1.034923 -1.449686
# TCGA-04-1362-01 -0.748878 -1.587117 -0.368833  2.07851  1.137323 -2.849686
# TCGA-04-1364-01  1.386022 -1.077217 -2.833033  2.88541  0.417723 -1.703186
# TCGA-04-1365-01 -0.748878 -1.587117  1.026667  2.92631  1.055923 -2.831186
#
#                     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-04-1348-01 -1.161227  1.373005 -1.843933 -0.089112
# TCGA-04-1357-01 -1.648627  1.421205 -0.700533 -0.324312
# TCGA-04-1362-01 -2.889527  0.163805 -2.797333 -0.784212
# TCGA-04-1364-01  0.590773  0.999505 -2.731333 -0.705912
# TCGA-04-1365-01 -0.571927  0.394805 -1.341533 -0.757312
#
# [5 rows x 20531 columns]

# %%
# Convert "day_to_birth" to age in years
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)

# Calculate the product of 'condition' and 'BRCA1', and add it as a new column
merged_data['condition_brca1_product'] = merged_data[condition_col] * merged_data['BRCA1']

# Calculate the product of 'condition' and 'BRCA2', and add it as a new column
merged_data['condition_brca2_product'] = merged_data[condition_col] * merged_data['BRCA2']

# Print the modified merged_data
merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-04-1348-01             44  -1.144492  4.363674 -0.531035  0.358628
# TCGA-04-1357-01             52  -0.681392  2.275374 -0.531035 -0.814372
# TCGA-04-1362-01             59  -0.298792  2.225074 -0.531035  0.300928
# TCGA-04-1364-01             61  -1.884192  5.459374 -0.531035 -0.296072
# TCGA-04-1365-01             87  -0.682892  1.917674 -0.531035 -0.014072
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-04-1348-01 -0.729078  0.64369  0.042406  1.447654  1.103801  ...
# TCGA-04-1357-01 -0.131978  0.10519  0.854706  0.423254  0.299901  ...
# TCGA-04-1362-01  0.047622 -0.65201 -0.421194  2.968654  1.154701  ...
# TCGA-04-1364-01 -0.551278 -0.97961  1.181606  2.309254  1.007501  ...
# TCGA-04-1365-01 -0.229678 -0.95741  0.478706  0.611454  0.902401  ...
#
#                     GNGT2    GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# sampleID
# TCGA-04-1348-01  0.660767  1.89921  0.277323 -0.963686 -1.161227  1.373005
# TCGA-04-1357-01  1.654867  2.59361  1.034923 -1.449686 -1.648627  1.421205
# TCGA-04-1362-01 -0.368833  2.07851  1.137323 -2.849686 -2.889527  0.163805
# TCGA-04-1364-01 -2.833033  2.88541  0.417723 -1.703186  0.590773  0.999505
# TCGA-04-1365-01  1.026667  2.92631  1.055923 -2.831186 -0.571927  0.394805
#
#                      SELP      SELS  condition_brca1_product  \
# sampleID
# TCGA-04-1348-01 -1.843933 -0.089112                 5.540253
# TCGA-04-1357-01 -0.700533 -0.324312              -105.689228
# TCGA-04-1362-01 -2.797333 -0.784212              -264.401724
# TCGA-04-1364-01 -2.731333 -0.705912                25.858806
# TCGA-04-1365-01 -1.341533 -0.757312                 7.761692
#
#                  condition_brca2_product
# sampleID
# TCGA-04-1348-01                80.336720
# TCGA-04-1357-01                -2.629404
# TCGA-04-1362-01                89.339838
# TCGA-04-1364-01                68.736907
# TCGA-04-1365-01               197.588705
#
# [5 rows x 20533 columns]

# %%
# Tumor types range from 01 - 09, normal types from 10 - 19.
# Create a function to check if the last two digits of a row index fall within a specified range
def mark_tumor(row_index):
    # Get the last two characters of the index and convert them to an integer
    last_two_digits = int(row_index[-2:])

    # Check if they fall within the range 01-09 and mark as 1
    if 1 <= last_two_digits <= 9:
        return 1
    # Check if they fall within the range 10-19 and mark as 0
    elif 10 <= last_two_digits <= 19:
        return 0
    else:
        return -1  # If not within the specified ranges, mark as -1

# Use the apply function to add the Tumor column to merged_data
merged_data['Tumor'] = merged_data.index.to_series().apply(mark_tumor)

# Update input_cols
input_cols = merged_data.columns

# Print the modified merged_data
merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-04-1348-01             44  -1.144492  4.363674 -0.531035  0.358628
# TCGA-04-1357-01             52  -0.681392  2.275374 -0.531035 -0.814372
# TCGA-04-1362-01             59  -0.298792  2.225074 -0.531035  0.300928
# TCGA-04-1364-01             61  -1.884192  5.459374 -0.531035 -0.296072
# TCGA-04-1365-01             87  -0.682892  1.917674 -0.531035 -0.014072
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-04-1348-01 -0.729078  0.64369  0.042406  1.447654  1.103801  ...
# TCGA-04-1357-01 -0.131978  0.10519  0.854706  0.423254  0.299901  ...
# TCGA-04-1362-01  0.047622 -0.65201 -0.421194  2.968654  1.154701  ...
# TCGA-04-1364-01 -0.551278 -0.97961  1.181606  2.309254  1.007501  ...
# TCGA-04-1365-01 -0.229678 -0.95741  0.478706  0.611454  0.902401  ...
#
#                    GNGT1     TULP3      PTRF     BCL6B     GSTK1      SELP  \
# sampleID
# TCGA-04-1348-01  1.89921  0.277323 -0.963686 -1.161227  1.373005 -1.843933
# TCGA-04-1357-01  2.59361  1.034923 -1.449686 -1.648627  1.421205 -0.700533
# TCGA-04-1362-01  2.07851  1.137323 -2.849686 -2.889527  0.163805 -2.797333
# TCGA-04-1364-01  2.88541  0.417723 -1.703186  0.590773  0.999505 -2.731333
# TCGA-04-1365-01  2.92631  1.055923 -2.831186 -0.571927  0.394805 -1.341533
#
#                      SELS  condition_brca1_product  condition_brca2_product  \
# sampleID
# TCGA-04-1348-01 -0.089112                 5.540253                80.336720
# TCGA-04-1357-01 -0.324312              -105.689228                -2.629404
# TCGA-04-1362-01 -0.784212              -264.401724                89.339838
# TCGA-04-1364-01 -0.705912                25.858806                68.736907
# TCGA-04-1365-01 -0.757312                 7.761692               197.588705
#
#                  Tumor
# sampleID
# TCGA-04-1348-01      1
# TCGA-04-1357-01      1
# TCGA-04-1362-01      1
# TCGA-04-1364-01      1
# TCGA-04-1365-01      1
#
# [5 rows x 20534 columns]

# %%
input_cols
# Out:
# Index(['days_to_birth', 'ARHGEF10L', 'HIF3A', 'RNF17', 'RNF10', 'RNF11',
#        'RNF13', 'GTF2IP1', 'REM1', 'MTVR2',
#        ...
#        'GNGT1', 'TULP3', 'PTRF', 'BCL6B', 'GSTK1', 'SELP', 'SELS',
#        'condition_brca1_product', 'condition_brca2_product', 'Tumor'],
#       dtype='object', length=20534)

# %%
# Calculate the number of samples marked as 1 in the Tumor column
tumor_1_count = (merged_data['Tumor'] == 1).sum()

# Calculate the number of samples marked as 0 in the Tumor column
tumor_0_count = (merged_data['Tumor'] == 0).sum()

# Calculate the number of samples marked as -1 in the Tumor column
tumor_minus_1_count = (merged_data['Tumor'] == -1).sum()

# Print the number of samples for each label along with respective explanations
print(f"Number of samples with Tumor = 1 (Cancer samples): {tumor_1_count}")
print(f"Number of samples with Tumor = 0 (Normal samples): {tumor_0_count}")
print(f"Number of samples with Tumor = -1 (Abnormal data): {tumor_minus_1_count}")
# Out:
# Number of samples with Tumor = 1 (Cancer samples): 300
# Number of samples with Tumor = 0 (Normal samples): 0
# Number of samples with Tumor = -1 (Abnormal data): 0

# %%
import pandas as pd
from precision_lasso import VariableSelection

# Step 1: Read the CSV file
#df = pd.read_csv("prepared_data.csv")

# Step 2: Select relevant columns and convert to numpy array
data_array = merged_data.values

# Normalize data
X = data_array
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)
zero_std_columns = np.where(std == 0)[0]
X = (X - mean) / std
X[:, zero_std_columns] = 0

y = merged_data['Tumor'].values

# Implementing k-fold cross-validation
def cross_validation(X, y, k=5):
    # Shuffle data
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    fold_size = len(X) // k
    accuracies = []

    for i in range(k):
        # Split data into train and test based on the current fold
        test_indices = indices[i*fold_size : (i+1)*fold_size]
        train_indices = np.setdiff1d(indices, test_indices)

        X_train, X_test = X_shuffled[train_indices], X_shuffled[test_indices]
        y_train, y_test = y_shuffled[train_indices], y_shuffled[test_indices]

        # Use the precision_lasso package for regression
        var_select = VariableSelection()
        var_select.fit(X_train, y_train)
        #predictions = var_select.predict(X_test) # need package update
        predictions = np.dot(X, var_select.getBeta())

        # Turn the predictions into binary values using a threshold of 0.5
        binary_predictions = (predictions > 0.5).astype(int)

        # Calculate accuracy for this fold
        accuracy = np.mean(binary_predictions == y_test)
        accuracies.append(accuracy)

    # Return average accuracy over all folds
    return np.mean(accuracies)

# Print average accuracy for 5-fold cross-validation
print(cross_validation(data_array, y))
# Out:
# <ipython-input-49-711e755720d6>:15: RuntimeWarning: invalid value encountered in divide
#   X = (X - mean) / std
# /usr/local/lib/python3.10/dist-packages/precision_lasso/helpingMethods.py:49: RuntimeWarning: invalid value encountered in divide
#   ts = beta / np.sqrt(var * sigma)
# /usr/local/lib/python3.10/dist-packages/precision_lasso/helpingMethods.py:49: RuntimeWarning: divide by zero encountered in divide
#   ts = beta / np.sqrt(var * sigma)
# /usr/local/lib/python3.10/dist-packages/precision_lasso/VariableSelection.py:183: RuntimeWarning: divide by zero encountered in log
#   return -np.log(p), np.array(betas)
# 1.0

# %%
# Step 3: Use the precision_lasso package for regression
# Instantiate the VariableSelection class
var_select = VariableSelection()

# Fit the model
var_select.fit(X, y)

# Retrieve the coefficients
coefficients = var_select.getBeta()
nlog_p_values = var_select.getNegLogP()

# %%
import numpy as np
for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values):
    if 'brca' in var.lower():
        print(var, coef, np.exp(-nlogp))
    if condition_col in var:
        print(var, coef, np.exp(-nlogp))
    if 'product' in var.lower():
        print(var, coef, np.exp(-nlogp))
# Out:
# days_to_birth [-8.62816615e-32] 2.0781346517720656e-64
# BRCA1 [1.4791142e-31] 1.882687491721266e-55
# BRCA2 [1.72563323e-31] 6.004944891476126e-61
# condition_brca1_product [0.] 1.0
# condition_brca1_product [0.] 1.0
# condition_brca2_product [1.01689101e-30] 1.6028356708630487e-47
# condition_brca2_product [1.01689101e-30] 1.6028356708630487e-47

# %%
# Hypothesis

# Input the variables of interest, cancer name, and condition variable
interest_variable = "BRCA gene"
interest_var = 'brca'
cancer_name = "Ovarian Cancer"
condition_variable = "Age"

# Generate hypothesis text
hypotheses_text = f'Hypothesis\n\n'
hypotheses_text += f'For the question "What is the relationship between {interest_variable} and {cancer_name} when considering the influence of {condition_variable}?", the following hypotheses can be proposed:\n\n'
hypotheses_text += f'Null Hypothesis (H0): There is no significant association between the expression of the {interest_variable} and {cancer_name}, and this association is not influenced by {condition_variable}. In other words, the coefficient of the {interest_variable} is equal to zero in the regression model, and {condition_variable} does not significantly affect the risk of {cancer_name}.\n\n'
hypotheses_text += f'Alternative Hypothesis (H1): There is an association between the expression of the {interest_variable} and {cancer_name}, and this association may be influenced by {condition_variable}. Specifically, the coefficient of the {interest_variable} is not equal to zero in the regression model, and {condition_variable} may have a significant impact on the risk of {cancer_name}, either positively or negatively.\n\n'
hypotheses_text += f'Interaction Hypothesis: Additionally, an interaction hypothesis can be considered, indicating that there is an interaction between the effect of the {interest_variable} and {condition_variable}. This suggests that the effect of the BRCA gene may vary across different {condition_variable} groups, potentially manifested as a significant interaction term between {condition_variable} and the {interest_variable} in the regression model.'

# Print the generated hypothesis text
print(hypotheses_text)
# Out:
# Hypothesis
#
# For the question "What is the relationship between BRCA gene and Ovarian Cancer when considering the influence of Age?", the following hypotheses can be proposed:
#
# Null Hypothesis (H0): There is no significant association between the expression of the BRCA gene and Ovarian Cancer, and this association is not influenced by Age. In other words, the coefficient of the BRCA gene is equal to zero in the regression model, and Age does not significantly affect the risk of Ovarian Cancer.
#
# Alternative Hypothesis (H1): There is an association between the expression of the BRCA gene and Ovarian Cancer, and this association may be influenced by Age. Specifically, the coefficient of the BRCA gene is not equal to zero in the regression model, and Age may have a significant impact on the risk of Ovarian Cancer, either positively or negatively.
#
# Interaction Hypothesis: Additionally, an interaction hypothesis can be considered, indicating that there is an interaction between the effect of the BRCA gene and Age. This suggests that the effect of the BRCA gene may vary across different Age groups, potentially manifested as a significant interaction term between Age and the BRCA gene in the regression model.

# %%
# Regression Model Report

# Create lists to store information about the variables of interest
interest_var_info = []
condition_var_info = []
product_var_info = []

# Extract information about variables related to interest_var
for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values):
    if interest_var in var.lower() and 'product' not in var.lower():
        interest_var_info.append((var, coef, np.exp(-nlogp)))
    if condition_col in var.lower():
        condition_var_info.append((var, coef, np.exp(-nlogp)))
    if 'product' in var.lower():
        product_var_info.append((var, coef, np.exp(-nlogp)))

# Generate the report "Regression Results"
regression_report = "Regression Results:\n\n"
regression_report += f"For {interest_var}:\n"
for variable_name, coefficient, p_value in interest_var_info:
    regression_report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"

regression_report += f"\nFor {condition_col}:\n"
for variable_name, coefficient, p_value in condition_var_info:
    regression_report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"

regression_report += f"\nFor Interaction Variable:\n"
for variable_name, coefficient, p_value in product_var_info:
    regression_report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"

# Print the generated report
print(regression_report)
# Out:
# Regression Results:
#
# For brca:
# BRCA1: Coefficient = [1.4791142e-31], p-value = 1.882687491721266e-55
# BRCA2: Coefficient = [1.72563323e-31], p-value = 6.004944891476126e-61
#
# For days_to_birth:
# days_to_birth: Coefficient = [-8.62816615e-32], p-value = 2.0781346517720656e-64
#
# For Interaction Variable:
# condition_brca1_product: Coefficient = [0.], p-value = 1.0
# condition_brca2_product: Coefficient = [1.01689101e-30], p-value = 1.6028356708630487e-47

# %%
# Interpretation of Regression Coefficients
# Create a function to interpret regression coefficients and p-values
def interpret_coefficient(variable_name, coefficient, p_value):
    interpretation = f"Variable: {variable_name}\n"

    if coefficient > 0:
        interpretation += "Coefficient is positive, "
    elif coefficient < 0:
        interpretation += "Coefficient is negative, "
    else:
        interpretation += "Coefficient is zero, "

    if p_value < 0.05:  # Assuming a significance level of 0.05
        interpretation += "and it is statistically significant (p-value < 0.05).\n\n"
    else:
        interpretation += "and it is not statistically significant (p-value >= 0.05).\n\n"

    return interpretation

# Create a report to interpret coefficients and p-values for all variables
interpretation_coefficient_report = "Interpretation of Regression Coefficients:\n\n"

for variable_name, coefficient, p_value in interest_var_info + condition_var_info + product_var_info:
    interpretation_coefficient_report += interpret_coefficient(variable_name, coefficient, p_value)

# Print the interpretation report
print(interpretation_coefficient_report)
# Out:
# Interpretation of Regression Coefficients:
#
# Variable: BRCA1
# Coefficient is positive, and it is statistically significant (p-value < 0.05).
#
# Variable: BRCA2
# Coefficient is positive, and it is statistically significant (p-value < 0.05).
#
# Variable: days_to_birth
# Coefficient is negative, and it is statistically significant (p-value < 0.05).
#
# Variable: condition_brca1_product
# Coefficient is zero, and it is not statistically significant (p-value >= 0.05).
#
# Variable: condition_brca2_product
# Coefficient is positive, and it is statistically significant (p-value < 0.05).

# %%
# Hypothesis Confirmation and Conclusion

significance_level = 0.05
# Create a function to determine if H0 or H1 is confirmed
def confirm_hypothesis(coefficient, p_value, variable_name, significance_level=0.05):
    if p_value >= significance_level:
        return f"H0 is not rejected: There is insufficient evidence to conclude a significant association between the expression of the {variable_name} gene and {cancer_name}, and {condition_variable}'s impact on the risk of {cancer_name} remains inconclusive."
    elif coefficient != 0 and p_value < significance_level:
        return f"H1 is confirmed: There is an association between the expression of the {variable_name} and {cancer_name}, and this association may be influenced by {condition_variable}. Specifically, the coefficient of the {interest_variable} is equal to {coefficient} in the regression model, and {condition_variable} may have a significant impact on the risk of {cancer_name}, either positively or negatively.\n\n"

# Create a report to determine and conclude H0 or H1 confirmation for interaction terms
hypothesis_confirmation_report = "Hypothesis Confirmation and Conclusion:\n\n"

for variable_name, coefficient, p_value in interest_var_info:
    confirmation = confirm_hypothesis(coefficient, p_value, variable_name)
    hypothesis_confirmation_report += f"Variable: {variable_name}\n"
    hypothesis_confirmation_report += f"Conclusion: {confirmation}\n\n"

# Create a report for interaction terms
interaction_report = "Interaction Term Interpretation:\n\n"

for variable_name, coefficient, p_value in product_var_info:

    # Extract the interesting variable name
    interest_variable = variable_name.split("_")[1]

    # Determine the interpretation based on coefficient and p-value
    interpretation = ""
    if coefficient > 0 and p_value < significance_level:
        interpretation = f"Positive interaction: As {condition} increases, the impact of {interest_variable} on {cancer_name} also increases."
    elif coefficient < 0 and p_value < significance_level:
        interpretation = f"Negative interaction: As {condition} increases, the impact of {interest_variable} on {cancer_name} decreases."
    elif p_value >= significance_level:
        interpretation = f"Non-significant interaction: The interaction effect between {condition} and {interest_variable} is not statistically significant."

    interaction_report += f"Interaction Term: {variable_name}\n"
    interaction_report += f"Conclusion: {interpretation}\n\n"

# Print the hypothesis confirmation report
print(hypothesis_confirmation_report)

# Print the interaction term interpretation report
print(interaction_report)
# Out:
# Hypothesis Confirmation and Conclusion:
#
# Variable: BRCA1
# Conclusion: H1 is confirmed: There is an association between the expression of the BRCA1 and Ovarian Cancer, and this association may be influenced by Age. Specifically, the coefficient of the BRCA gene is equal to [1.4791142e-31] in the regression model, and Age may have a significant impact on the risk of Ovarian Cancer, either positively or negatively.
#
#
#
# Variable: BRCA2
# Conclusion: H1 is confirmed: There is an association between the expression of the BRCA2 and Ovarian Cancer, and this association may be influenced by Age. Specifically, the coefficient of the BRCA gene is equal to [1.72563323e-31] in the regression model, and Age may have a significant impact on the risk of Ovarian Cancer, either positively or negatively.
#
#
#
#
# Interaction Term Interpretation:
#
# Interaction Term: condition_brca1_product
# Conclusion: Non-significant interaction: The interaction effect between age and brca1 is not statistically significant.
#
# Interaction Term: condition_brca2_product
# Conclusion: Positive interaction: As age increases, the impact of brca2 on Ovarian Cancer also increases.
